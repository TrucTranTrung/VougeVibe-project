# %%
from deepface import DeepFace
import tensorflow as tf
import h5py
import cv2

# %%
image_path="C:\\Users\\ASUS\\Downloads\\z5881389648459_8ca28c8e835040a9583686aa8bf66e63.jpg"
image = cv2.imread(image_path)
result = DeepFace.analyze(image, actions=['gender'], enforce_detection=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 image_path="C:\\Users\\ASUS\\Downloads\\z5881389648459_8ca28c8e835040a9583686aa8bf66e63.jpg"
#       2 image = cv2.imread(image_path)
# ----> 3 result = DeepFace.analyze(image, actions=['gender'], enforce_detection=False)
#
# File d:\Anaconda\Lib\site-packages\deepface\DeepFace.py:253, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     166 def analyze(
#     167     img_path: Union[str, np.ndarray],
#     168     actions: Union[tuple, list] = ("emotion", "age", "gender", "race"),
#    (...)
#     174     anti_spoofing: bool = False,
#     175 ) -> List[Dict[str, Any]]:
#     176     """
#     177     Analyze facial attributes such as age, gender, emotion, and race in the provided image.
#     178     Args:
#    (...)
#     251             - 'white': Confidence score for White ethnicity.
#     252     """
# --> 253     return demography.analyze(
#     254         img_path=img_path,
#     255         actions=actions,
#     256         enforce_detection=enforce_detection,
#     257         detector_backend=detector_backend,
#     258         align=align,
#     259         expand_percentage=expand_percentage,
#     260         silent=silent,
#     261         anti_spoofing=anti_spoofing,
#     262     )
#
# File d:\Anaconda\Lib\site-packages\deepface\modules\demography.py:181, in analyze(img_path, actions, enforce_detection, detector_backend, align, expand_percentage, silent, anti_spoofing)
#     178     obj["age"] = int(apparent_age)
#     180 elif action == "gender":
# --> 181     gender_predictions = modeling.build_model(
#     182         task="facial_attribute", model_name="Gender"
#     183     ).predict(img_content)
#     184     obj["gender"] = {}
#     185     for i, gender_label in enumerate(Gender.labels):
#
# File d:\Anaconda\Lib\site-packages\deepface\modules\modeling.py:96, in build_model(task, model_name)
#      94 model = models[task].get(model_name)
#      95 if model:
# ---> 96     cached_models[task][model_name] = model()
#      97 else:
#      98     raise ValueError(f"Invalid model_name passed - {task}/{model_name}")
#
# File d:\Anaconda\Lib\site-packages\deepface\models\demography\Gender.py:40, in GenderClient.__init__(self)
#      39 def __init__(self):
# ---> 40     self.model = load_model()
#      41     self.model_name = "Gender"
#
# File d:\Anaconda\Lib\site-packages\deepface\models\demography\Gender.py:83, in load_model(url)
#      80     logger.info(f"{os.path.basename(output)} will be downloaded...")
#      81     gdown.download(url, output, quiet=False)
# ---> 83 gender_model.load_weights(output)
#      85 return gender_model
#
# File d:\Anaconda\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File d:\Anaconda\Lib\site-packages\tf_keras\src\saving\legacy\save.py:485, in load_weights(model, filepath, by_name, skip_mismatch, options)
#     479     raise ValueError(
#     480         "Unable to load weights saved in HDF5 format into a "
#     481         "subclassed Model which has not created its variables yet. "
#     482         "Call the Model first, then load the weights."
#     483     )
#     484 model._assert_weights_created()
# --> 485 with h5py.File(filepath, "r") as f:
#     486     if "layer_names" not in f.attrs and "model_weights" in f:
#     487         f = f["model_weights"]
#
# AttributeError: module 'h5py' has no attribute 'File'
